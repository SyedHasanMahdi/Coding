# %%
# Run this cell to render a mitosheet
# See mito's documentation here: https://docs.trymito.io/how-to/creating-a-mitosheet
# Join our Discord for support here: https://discord.gg/XdJSZyejJU

import mitosheet
mitosheet.sheet(analysis_to_replay="id-pcqzaespsh")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-pcqzaespsh", "analysisToReplay": null, "code": [], "stepSu…

# %%
from mitosheet import *; register_analysis("id-pcqzaespsh");
    
# Imported pd.csv
import pandas as pd
pd = pd.read_csv(r'C:\Users\user\Documents\Baba\Numpy\pd.csv')

# Deleted columns 3
pd.drop(['3'], axis=1, inplace=True)
