# %%
from youtube_video_scraping import *
response=youtube.get_video_info(video_url='https://www.youtube.com/shorts/QGpEmPLXZOQ')
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from youtube_video_scraping import *
#       2 response=youtube.get_video_info(video_url='https://www.youtube.com/shorts/QGpEmPLXZOQ')
#       3 print(response)
#
# ModuleNotFoundError: No module named 'youtube_video_scraping'

# %%
from youtube_video_scraping import *
response=youtube.comments(youtube_link='https://www.youtube.com/shorts/QGpEmPLXZOQ')
# Out:
# Progress: 100%|██████████| 200.0/200 [06:40<00:00,  2.00s/it]
# ...
# Progress: 100%|██████████| 200/200 [00:06<00:00, 32.79it/s]
